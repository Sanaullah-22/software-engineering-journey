# %% [markdown]
#                                          TAKING USER INPUT

# %%
a  = input("Enter Your Name")
b = input("Enter Your Age")

print ("Name :",a , "age :" , b)
# Out:
# Enter Your Name sanauallah
# Enter Your Age 18
# Name : sanauallah age : 18

# %% [markdown]
#                                     Adding two inputs  numbers

# %%
a = input("Enter First Number")   
a = int(a)
# By Default input give us string 
#now convert string to int or float
#  for converting we have two method
#1. int(input("Enter a no))
#2. a=
b = int(input('Enter Second Number'))                
sum = a + b
print("Sum = ",sum)
# Out:
# Enter First Number 33
# Enter Second Number 33
# Sum =  66
