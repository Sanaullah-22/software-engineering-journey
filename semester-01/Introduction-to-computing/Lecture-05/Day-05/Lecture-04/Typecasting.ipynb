# %% [markdown]
#                             TYPECASTING
#            . Conversion of one data type into another

# %%
a = 32
print(type(a) ,a )
#cnverting  a to and str
b = str(a)
print(type(b) ,b )
c = 2
d = float(c)
print(type(d) , d)
# Out:
# <class 'int'> 32
# <class 'str'> 32
# <class 'float'> 2.0
