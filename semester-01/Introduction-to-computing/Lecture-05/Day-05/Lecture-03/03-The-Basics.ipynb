# %% [markdown]
#                             VARIABLE AND DATA TYPES

# %% [markdown]
#         VARIABLE=> a variable is created when ever you assign a value to it using assignment operator
#         Assignment Operator=> is eqaul (=) is assignment operator bcz we assign a value through this
#         .in python variable are us eto store data that can be used and manipulate throughout a program.
#         .A variable is created the momment you assign a value to it using assignment operator ( = ).
#         Pyhton is dynamically typed language which mena we dont need to specify the type of aur variable

# %%
age=23
print(age)
# Out:
# 23

# %%
name="sanny"
print(name)
# Out:
# sanny

# %%
cgpa=3.5

# %%
print(type(cgpa),cgpa)
# Out:
# <class 'float'> 3.5

# %% [markdown]
#                                     Rules of Defining a variable in python

# %% [markdown]
#         1.Variable names must start with letter (a-z , A-Z) or an Underscore ( _ )
#         2.They Can Contain Letter , Number , and UnderScore.
#         3.Variable names are case sensetive (age and Age ) are diffrent variable name.
#         4.Avoid using pyhton keywords (if, for , while) as a variable

# %%
32age = 23 #invalid bcz varibale should start with letter or undescore
# Out:
#   Cell In[8], line 1
#     32age = 23 #invalid bcz varibale should start with letter or undescore
#      ^
# SyntaxError: invalid decimal literal

# %%
age = 32
print(age)
# Out:
# 32

# %%
ag$$e = 32 this is inavalid bcz variable dont contain special character without underscore
# Out:
#   Cell In[11], line 1
#     ag$$e = 32 this is inavalid bcz variable dont contain special character
#       ^
# SyntaxError: invalid syntax

# %%
_age = 35 #this is valid
print(_age)
# Out:
# 35

# %% [markdown]
#                             Datatypes in Python

# %% [markdown]
#                          Pyhton several built-in data types
#             1.integer => int => whole number (e.g.,10,20 ,-5)
#             2.Float => float => decimal number (3.14, -0.234)
#             3.String => str => text data console in quotes ( "hello" , 'pyhton')
#             4.Booleans => bool => True or False
#             Lists => Orderd ,muteable collection (e.g. [1,2,3])
#             Tuple => Orderd , immuteable collection (e.g. (1,2,3))
#             Sets => Unorderd collection of unique elements {1,2,3}
#             Dictionaries => Key-Value pairs e.g {"name": "alice","age" : 23}

# %%
age = 23 
type(age)
# Out:
# int

# %%
name = "sanny"
print(type(name) , name)
# Out:
# <class 'str'> sanny

# %%
cgpa = 3.9
print(type(cgpa) , cgpa)
# Out:
# <class 'float'> 3.9

# %%
is_completed = True
print(type(is_completed) , is_completed )
# Out:
# <class 'bool'> True
