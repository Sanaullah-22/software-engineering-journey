# %% [markdown]
#                                         PYTHON BY CODE WITH HARRY

# %% [markdown]
#                         what is Programming----- way of communacating with computer
# .Programming--Solving problem through code and turning ideas into actionable instruction
# . Rules Thats need to be followed if u want to communicate with computer is called Syntax.
# . if you dont follow these rule computer give u the thing called Error

# %% [markdown]
# . Rules Thats need to be followed if u want to communicate with computer is called Syntax.
# . if you dont follow these rule computer give u the thing called Error

# %% [markdown]
# What Is Python
# .High level interpreted langauge
