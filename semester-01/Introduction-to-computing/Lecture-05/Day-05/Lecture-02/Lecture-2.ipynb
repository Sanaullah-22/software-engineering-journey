# %%
print("hello,world")
# Out:
# hello,world

# %% [markdown]
# .Print is an function and inside the () is argument

# %% [markdown]
#                                         Python Syntex

# %%
print("i am a webdesigner")
# Out:
# i am a webdesigner

# %%
print(30)
# Out:
# 30

# %%
Comment is a way to instruct the computer hey ignore these line or peace of code
#if(5>3):
 #   print("Hello")      #indentation =>space before syntex they tell either am inside the block or not
# Out:
#   Cell In[6], line 1
#     Comment is a way to instruct the computer hey ignore these line or peace of code
#                  ^
# SyntaxError: invalid syntax
